# %% [markdown]
# ### 클래스

# %%
class Cookie:
    pass

a = Cookie()

print(type(a))
# Out:
# <class '__main__.Cookie'>

# %%
class FourCal:
    # 클래스에서 함수를 사용할 때는 반드시 self 매개변수 사용
    # self -> 실행 시점점의 함수를 포함하는 객체 자신을 가르키는 변수
    def setData(self, first, second): # 변수 초기화
        self.first = first
        self.second = second
    
    def add(self): # 함수
        return self.first + self.second
    def sub(self):
        return self.first - self.second
    def mul(self):
        return self.first * self.second
    def div(self):
        return self.first / self.second
        

cal1 = FourCal() # 객체 생성 => 프로그램에서 사용가능한 상태(메모리에 변수와 함수가 올라가는 상태)

cal1.setData(10,30)

print(cal1.add(),cal1.sub(),cal1.mul(),cal1.div())
# Out:
# 40 -20 300 0.3333333333333333
